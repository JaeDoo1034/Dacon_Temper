# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns; sns.set()
import chart_studio.plotly as py
import cufflinks as cf
plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'
cf.go_offline()

import matplotlib.font_manager as fm
path = 'C:\Windows\Fonts\malgunbd.ttf'
font_name = fm.FontProperties(fname=path).get_name()
plt.rc('font', family=font_name)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Data = pd.read_csv('data/Data_30.csv')

# %%
Data = Data.set_index('id')

# %% [markdown]
# ##### 기온의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X00','X07','X28','X31','X32']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('기온',fontsize =10)
plt.show()

# %% [markdown]
# ##### 현지기압의 차이 분석

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X01','X06','X22','X27','X29']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('현지기압',fontsize =10)
plt.show()

# %% [markdown]
# ##### 해면기압의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X05','X08','X29','X23','X33']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('해면기압',fontsize =10)
plt.show()

# %% [markdown]
# ##### 일일 누적강수량의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X04','X10','X21','X36','X39']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('일일 누적강수량',fontsize =10)
plt.show()

# %% [markdown]
# ##### 일일 누적일사량의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X11','X14','X16','X19','X34']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('일일 누적일사량',fontsize =10)
plt.show()

# %% [markdown]
# ##### 습도의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X12','X20','X30','X37','X38']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('습도',fontsize =10)
plt.show()

# %% [markdown]
# ##### 풍속의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X02','X03','X18','X24','X26']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('풍속',fontsize =10)
plt.show()

# %% [markdown]
# ##### 풍향의 차이

# %%
plt.figure(figsize = (8,8))
Data.loc[:,['X13','X15','X17','X25','X35']].mean().plot()
plt.xticks([0,1,2,3,4],['A지역','B지역','C지역','D지역','E지역'])
plt.xlabel('지역별 차이',fontsize = 10)
plt.ylabel('풍향',fontsize =10)
plt.show()
